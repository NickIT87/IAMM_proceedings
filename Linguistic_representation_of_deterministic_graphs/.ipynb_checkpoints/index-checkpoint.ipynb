# %%
import networkx as nx
from networkx.algorithms import isomorphism

from DataBenchmarks.data import print_data, TestCases as T, sample_exists, sample_not_exists
#from DataBenchmarks.flowerGraph import *
from AlgorithmsLibraries.alglib_version_02_current import *
#from AlgorithmsLibraries.debug_helpers import *

import sys
from contextlib import contextmanager


@contextmanager
def suppress_output():
    original_stdout = sys.stdout
    sys.stdout = None
    try:
        yield
    finally:
        sys.stdout = original_stdout

# %%
T.sample.defining_pair
# Out:
# DefiningPair(C=('01242154312310', '02352510', '02130214210', '01320213025310', '01323510', '02141345320', '015452034531210', '0214130251320', '01352101421320'), L=('0235431302105', '012410120314'))

# %%
sample_exists
# Out:
# (('14520542321241',
#   '14501',
#   '16521263301',
#   '143513361',
#   '126356341',
#   '1635130541',
#   '16536242102541',
#   '16253621',
#   '16345201',
#   '143315362561',
#   '10315361'),
#  ('1653624',
#   '1436124',
#   '1436521',
#   '12635621',
#   '163423',
#   '105423',
#   '10334210',
#   '1054210'))

# %%
sample_not_exists
# Out:
# (('14520542321241',
#   '14501',
#   '16521263301',
#   '143513361',
#   '126356341',
#   '1635130541',
#   '16536242102541',
#   '16253621',
#   '16345201',
#   '143315362561',
#   '10315361',
#   '191'),
#  ('1653624',
#   '1436124',
#   '1436521',
#   '12635621',
#   '163423',
#   '105423',
#   '10334210',
#   '1054210'))

# %%
G = ap_graph(T.sample.defining_pair.C, T.sample.defining_pair.L, T.sample.root_label)
G.name = 'Etalon G'
print_data(G)

# %%
S = ap_graph(sample_exists[0], sample_exists[1])
S.name = 'sample_exists'
print_data(S)

# %%
ap_graph(sample_not_exists[0], sample_not_exists[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ap_graph(sample_not_exists[0], sample_not_exists[1])
#
# File ~/programming/IAMM_proceedings/Linguistic_representation_of_deterministic_graphs/AlgorithmsLibraries/alglib_version_02_current.py:254, in ap_graph(cycles, leaves, root_label)
#     252     dgraph_g = ar_nodes(dgraph_g)
#     253 # ================ STEPS 3,4,5 Check each word in (C, L) =================
# --> 254 verify_deterministic_graph(dgraph_g, cycles, leaves, root)
#     255 return dgraph_g
#
# File ~/programming/IAMM_proceedings/Linguistic_representation_of_deterministic_graphs/AlgorithmsLibraries/alglib_version_02_current.py:108, in verify_deterministic_graph(dgraph, cycles, leaves, root)
#     106     all_leafs.pop(checked_node, None)
#     107 if all_leafs:
# --> 108     raise service_error(
#     109         f"Vertex id/label: {all_leafs} is not in the scope of L.")
#     110 for c_word in cycles:
#     111     if get_node_id_by_word(dgraph, c_word, root) != root:
#
# ValueError: Incorrect data. Graph is not exists!
# Vertex id/label: {87: '9'} is not in the scope of L.

# %%
c_pair_of_G_by_ac_pair = ac_pair(G)
c_pair_of_G_by_compression = compression(T.sample.defining_pair.C, T.sample.defining_pair.L)
c_pair_of_G_by_compression
# Out:
# UNCOMPRESSED DEFINING PAIR:
#  ('01242154312310', '02352510', '02130214210', '01320213025310', '01323510', '02141345320', '015452034531210', '0214130251320', '01352101421320') ('0235431302105', '012410120314')
# 101  Operation 3 is performed. word=01323510, modified=013510,
#
#  global_deleted_paths={'0132'}
#
# 102  Operation 3 is performed. word=02352510, modified=023510,
#
#  global_deleted_paths={'0132', '0152'}
#
# 103  Operation 3 is performed. word=02141345320, modified=021345320,
#
#  global_deleted_paths={'0132', '0152', '0214'}
#
# 104  Operation 3 is performed. word=0214130251320, modified=02130251320,
#
#  global_deleted_paths={'0132', '0152', '0214'}
#
# 105  Operation 3 is performed. word=01242154312310, modified=012154312310,
#
#  global_deleted_paths={'0132', '0152', '0214', '0124'}
#
# 106  Operation 3 is performed. word=012154312310, modified=0154312310,
#
#  global_deleted_paths={'0124', '012', '0214', '0132', '0152'}
#
# 107  Operation 3 is performed. word=01320213025310, modified=013213025310,
#
#  global_deleted_paths={'0124', '012', '01320', '0214', '0132', '0152'}
#
# 108  Operation 3 is performed. word=01352101421320, modified=013521421320,
#
#  global_deleted_paths={'0124', '012', '01320', '0214', '0132', '0135210', '0152'}
#
# 109  Operation 3 is performed. word=015452034531210, modified=0152034531210,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '0214', '0132', '0135210', '0152'}
#
# 110  Operation 3 is performed. word=0152034531210, modified=01520345310,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '0214', '0132', '0135210', '0152'}
#
# 111  Operation 3 is performed. word=012410120314, modified=0124120314,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '012410', '0214', '0132', '0135210', '0152'}
#
# 112  Operation 3 is performed. word=0235431302105, modified=02354302105,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '012410', '0214', '0132', '0135210', '0152', '0235431'}
#
# 113  Operation 4 is performed. sigma=023510 reversed=015320.
#
# 114  Operation 4 is performed. sigma=0154312310 reversed=0132134510.
#
# 115  Operation 4 is performed. sigma=01520345310 reversed=01354302510.
#
# 116  Operation 4 is performed. sigma=02130214210 reversed=01241203120.
#
# 117  Operation 5 is performed. LEFT Begin. cword=015320, modified=01320, w1=0153, w2=013 word=013510
#
# 118  Operation 5 LEFT END: cword=021345320, modified=021345310 w1reversed=320, w2=310 End. word=01320
#
# 119  Operation 4 is performed. sigma=021345310 reversed=013543120.
#
# 120  Operation 5 is performed. RIGHT Begin. cword=0132134510, modified=02134510, w1=0132, w2=02 word=01320
#
# 121  Operation 4 is performed. sigma=02134510 reversed=01543120.
#
# 122  Operation 5 LEFT END: cword=02130251320, modified=02130251310 w1reversed=320, w2=310 End. word=01320
#
# 123  Operation 3 is performed. word=02130251310, modified=021302510,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '012410', '0214', '0132', '0135210', '013', '0152', '0235431'}
#
# 124  Operation 4 is performed. sigma=021302510 reversed=015203120.
#
# 125  Operation 5 is performed. RIGHT Begin. cword=013213025310, modified=0213025310, w1=0132, w2=02 word=01320
#
# 126  Operation 4 is performed. sigma=0213025310 reversed=0135203120.
#
# 127  Operation 5 LEFT END: cword=013521421320, modified=013521421310 w1reversed=320, w2=310 End. word=01320
#
# 128  Operation 3 is performed. word=013521421310, modified=0135214210,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '012410', '0214', '0132', '0135210', '013', '0152', '0235431'}
#
# 129  Operation 4 is performed. sigma=0135214210 reversed=0124125310.
#
# 130  Operation 5 is performed. LEFT Begin. lword=02354302105, modified=01354302105 w1=023, w2=013 word=01320
#
# 131  Operation 5 is performed. RIGHT Begin. cword=013543120, modified=01543120, w1=0135, w2=015 word=013510
#
# 132  Operation 1 is performed.
#
# 133  Operation 5 RIGHT END: cword=0124125310, modified=012412510 w1reversed=5310, w2=510 word=013510
#
# 134  Operation 5 is performed. RIGHT Begin. cword=0135203120, modified=015203120, w1=0135, w2=015 word=013510
#
# 135  Operation 1 is performed.
#
# 136  Operation 5 is performed. RIGHT Begin. cword=01354302510, modified=0154302510, w1=0135, w2=015 word=013510
#
# 137  Operation 4 is performed. sigma=0154302510 reversed=0152034510.
#
# 138  Operation 5 is performed. RIGHT BEGIN lword=01354302105, modified=0154302105 w1=0135, w2=015 word=013510
#
# 139  Operation 5 RIGHT END: cword=0152034510, modified=015203120 w1reversed=34510, w2=3120 word=01543120
#
# 140  Operation 1 is performed.
#
# 141  Operation 5 is performed. RIGHT BEGIN lword=0154302105, modified=021302105 w1=01543, w2=0213 word=01543120
#
# 142  Operation 5 is performed. RIGHT Begin. cword=01241203120, modified=015203120, w1=012412, w2=0152 word=012412510
#
# 143  Operation 1 is performed.
#
# 144  Operation 5 is performed. RIGHT BEGIN lword=0124120314, modified=01520314 w1=012412, w2=0152 word=012412510
#
# 145  Operation 5 is performed. RIGHT BEGIN lword=01520314, modified=021314 w1=015203, w2=0213 word=015203120
#
# 146  Operation 3 is performed. word=021314, modified=0214,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '0213', '012410', '0214', '0132', '0135210', '013', '0152', '0235431'}
#
# 147  Operation 5 is performed. LEFT Begin. lword=021302105, modified=015202105 w1=02130, w2=01520 word=015203120
#
# 148  Operation 3 is performed. word=015202105, modified=0152105,
#
#  global_deleted_paths={'0124', '0154', '012', '01320', '0213', '01520', '012410', '0214', '0132', '0135210', '013', '0152', '0235431'}
#
# 149  Operation 5 is performed. LEFT Begin. lword=0152105, modified=0124105 w1=01521, w2=01241 word=012412510
#
#  Path optimization 3. RIGHT Begin. c_word=01320, shortest_word_before=01320, w1=0132, w2=02
#
# SHORTEST WORD after:  020
#  Path optimization 3. RIGHT Begin. c_word=01320, shortest_word_before=01320, w1=0132, w2=02
#
# SHORTEST WORD after:  020
# CHECK GLOBAL PATH WORD:  020 0
#  Path optimization 3. RIGHT Begin. c_word=01320, shortest_word_before=0132, w1=0132, w2=02
#
# SHORTEST WORD after:  02
#  Path optimization 3. RIGHT Begin. c_word=01320, shortest_word_before=0132, w1=0132, w2=02
#
# SHORTEST WORD after:  02
#  Path optimization 3. RIGHT Begin. c_word=013510, shortest_word_before=0135210, w1=0135, w2=015
#
# SHORTEST WORD after:  015210
#  Path optimization 3. RIGHT Begin. c_word=013510, shortest_word_before=0135210, w1=0135, w2=015
#
# SHORTEST WORD after:  015210
#  Path optimization 3. LEFT Begin. c_word=012412510, shortest_word_before=015210, w1=01521, w2=01241
#
# SHORTEST WORD after:  012410
#  Path optimization 3. LEFT Begin. c_word=012412510, shortest_word_before=015210, w1=01521, w2=01241
#
# SHORTEST WORD after:  012410
#  Path optimization 3. LEFT Begin. c_word=01320, shortest_word_before=0235431, w1=023, w2=013
#
# SHORTEST WORD after:  0135431
#  Path optimization 3. LEFT Begin. c_word=01320, shortest_word_before=0235431, w1=023, w2=013
#
# SHORTEST WORD after:  0135431
#  Path optimization 3. RIGHT Begin. c_word=013510, shortest_word_before=0135431, w1=0135, w2=015
#
# SHORTEST WORD after:  015431
#  Path optimization 3. RIGHT Begin. c_word=013510, shortest_word_before=0135431, w1=0135, w2=015
#
# SHORTEST WORD after:  015431
#  Path optimization 3. RIGHT Begin. c_word=01543120, shortest_word_before=015431, w1=01543, w2=0213
#
# SHORTEST WORD after:  02131
#  Path optimization 3. RIGHT Begin. c_word=01543120, shortest_word_before=015431, w1=01543, w2=0213
#
# SHORTEST WORD after:  02131
# CHECK GLOBAL PATH WORD:  02131 021
# {'compressed_pair': (('01320', '013510', '01543120', '012412510', '015203120'),
#   ('0214', '0124105')),
#  'graph_exists': True}

# %%
c_pair_of_G_by_ac_pair
# Out:
# (('01320', '013510', '012412510', '01543120', '015203120'),
#  ('0214', '0124105'))

# %%
c_pair_of_G_by_compression = c_pair_of_G_by_compression['compressed_pair']
c_pair_of_G_by_compression
# Out:
# (('01320', '013510', '01543120', '012412510', '015203120'),
#  ('0214', '0124105'))

# %%
def tuple_to_set(t):
    return {frozenset(subtuple) for subtuple in t}

set1 = tuple_to_set(c_pair_of_G_by_ac_pair)
set2 = tuple_to_set(c_pair_of_G_by_compression)

if set1 == set2:
    print("Pair is equal: ", set1 == set2)
# Out:
# Pair is equal:  True

# %%
with suppress_output():
    sample_compressed = compression(sample_exists[0], sample_exists[1])

ac_pair(S) == sample_compressed['compressed_pair']
# Out:
# True

# %%
G1 = ap_graph(c_pair_of_G_by_ac_pair[0], c_pair_of_G_by_ac_pair[1], '0')
G2 = ap_graph(c_pair_of_G_by_compression[0], c_pair_of_G_by_compression[1], '0')

GM = isomorphism.GraphMatcher(G, G1)
GM1 = isomorphism.GraphMatcher(G, G2)
GM2 = isomorphism.GraphMatcher(G1, G2)
if GM.is_isomorphic() and GM1.is_isomorphic() and GM2.is_isomorphic():
    print("Graphs is isomorfic")
# Out:
# Graphs is isomorfic

# %%
S1 = ap_graph(sample_compressed['compressed_pair'][0], sample_compressed['compressed_pair'][1], '1')
SM = isomorphism.GraphMatcher(S, S1)
SM.is_isomorphic()
# Out:
# True
